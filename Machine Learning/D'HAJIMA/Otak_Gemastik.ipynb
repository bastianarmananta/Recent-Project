# %%
import pandas as pd
import numpy as np
import regex
import re
import warnings

from tqdm import tqdm
from sklearn.metrics import confusion_matrix, accuracy_score
from nltk.tokenize import WordPunctTokenizer
from bs4 import BeautifulSoup
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import RidgeClassifier
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn import svm
from gensim.models import FastText

# %%
bundir1 = pd.read_csv('Data_Twitter/bunuh_diri/afifdhiaamru.csv')
bundir2 = pd.read_csv('Data_Twitter/bunuh_diri/rifky_ohorella.csv')
depresi1 = pd.read_csv('Data_Twitter/depresi/emmamoez.csv')
depresi2 = pd.read_csv('Data_Twitter/depresi/sukmaay_asmaran.csv')
bully1 = pd.read_csv('Data_Twitter/korban_bully/hermionyyye.csv')
bully2 = pd.read_csv('Data_Twitter/Korban_bully/foxsunyoung.csv')
seksual_abuse1 = pd.read_csv('Data_Twitter/pelecehan_seksual/thisisnotdayrah.csv')
seksual_abuse2 = pd.read_csv('Data_Twitter/pelecehan_seksual/jekaxjk.csv')
netral1 = pd.read_csv('Data_Twitter/netral/Afiiqaaahh.csv')
netral2 = pd.read_csv('Data_Twitter/netral/astriferdiana.csv')
netral3 = pd.read_csv('Data_Twitter/netral/aurelmayorii.csv')
netral4 = pd.read_csv('Data_Twitter/netral/Celine_JKT48.csv')
netral5 = pd.read_csv('Data_Twitter/netral/Eve_JKT48.csv')
netral6 = pd.read_csv('Data_Twitter/netral/FaisalBasri.csv')
netral7 = pd.read_csv('Data_Twitter/netral/Jinan_JKT48.csv')
netral8 = pd.read_csv('Data_Twitter/netral/R_AninJKT48.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-eb770343181f> in <module>()
# ----> 1 bundir1 = pd.read_csv('Data_Twitter/bunuh_diri/afifdhiaamru.csv')
#       2 bundir2 = pd.read_csv('Data_Twitter/bunuh_diri/rifky_ohorella.csv')
#       3 depresi1 = pd.read_csv('Data_Twitter/depresi/emmamoez.csv')
#       4 depresi2 = pd.read_csv('Data_Twitter/depresi/sukmaay_asmaran.csv')
#       5 bully1 = pd.read_csv('Data_Twitter/korban_bully/hermionyyye.csv')
#
# ...

# %%
tweet_bundir1 = bundir1.iloc[:,-1].values
tweet_bundir2 = bundir2.iloc[:,-1].values
tweet_depresi1 = depresi1.iloc[:,-1].values
tweet_depresi2 = depresi2.iloc[:,-1].values
tweet_bully1 = bully1.iloc[:,-1].values
tweet_bully2 = bully2.iloc[:,-1].values
tweet_seks_abuse1 = seksual_abuse1.iloc[:,-1].values
tweet_seks_abuse2 = seksual_abuse2.iloc[:,-1].values
tweet_netral1 = netral1.iloc[:,-1].values
tweet_netral2 = netral2.iloc[:,-1].values
tweet_netral3 = netral3.iloc[:,-1].values
tweet_netral4 = netral4.iloc[:,-1].values
tweet_netral5 = netral5.iloc[:,-1].values
tweet_netral6 = netral6.iloc[:,-1].values
tweet_netral7 = netral7.iloc[:,-1].values
tweet_netral8 = netral8.iloc[:,-1].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3a65bc528ec5> in <module>()
# ----> 1 tweet_bundir1 = bundir1.iloc[:,-1].values
#       2 tweet_bundir2 = bundir2.iloc[:,-1].values
#       3 tweet_depresi1 = depresi1.iloc[:,-1].values
#       4 tweet_depresi2 = depresi2.iloc[:,-1].values
#       5 tweet_bully1 = bully1.iloc[:,-1].values
#
# NameError: name 'bundir1' is not defined

# %%
combine = np.concatenate((tweet_bundir1
                         ,tweet_bundir2
                         ,tweet_depresi1
                         ,tweet_depresi2
                         ,tweet_bully1
                         ,tweet_bully2
                         ,tweet_seks_abuse1
                         ,tweet_seks_abuse2
                         ,tweet_netral1
                         ,tweet_netral2
                         ,tweet_netral3
                         ,tweet_netral4
                         ,tweet_netral5
                         ,tweet_netral6
                         ,tweet_netral7
                         ,tweet_netral8), axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c5878494e512> in <module>()
# ----> 1 combine = np.concatenate((tweet_bundir1
#       2                          ,tweet_bundir2
#       3                          ,tweet_depresi1
#       4                          ,tweet_depresi2
#       5                          ,tweet_bully1
#
# NameError: name 'tweet_bundir1' is not defined

# %%
tok = WordPunctTokenizer()
pat1 = r'@[A-Za-z0-9]+'
pat2 = r'https?://[A-Za-z0-9./]+'
pat3 = r'^RT[\s]+'
combined_pat = r'|'.join((pat1, pat2, pat3))
def tweet_cleaner(text):
    soup = BeautifulSoup(text, 'lxml')
    souped = soup.get_text()
    stripped = re.sub(combined_pat, '', souped)
    try:
        clean = stripped.decode("utf-8-sig").replace(u"\ufffd", "?")
    except:
        clean = stripped
    letters_only = re.sub("[^a-zA-Z]", " ", clean)
    lower_case = letters_only.lower()
    # During the letters_only process two lines above, it has created unnecessay white spaces,
    # I will tokenize and join together to remove unneccessary white spaces
    words = tok.tokenize(lower_case)
    return (" ".join(words)).strip()

testing = combine
test_result = []
for t in testing:
    test_result.append(tweet_cleaner(t))
test_result

# %%
panjang_tweet_bundir1 = len(tweet_bundir1)
panjang_tweet_bundir2 = len(tweet_bundir2)
panjang_tweet_depresi1 = len(tweet_depresi1)
panjang_tweet_depresi2 = len(tweet_depresi2)
panjang_tweet_bully1 = len(tweet_bully1)
panjang_tweet_bully2 = len(tweet_bully2)
panjang_tweet_seks_abuse1 = len(tweet_seks_abuse1)
panjang_tweet_seks_abuse2 = len(tweet_seks_abuse2)
panjang_tweet_netral1 = len(tweet_netral1)
panjang_tweet_netral2 = len(tweet_netral2)
panjang_tweet_netral3 = len(tweet_netral3)
panjang_tweet_netral4 = len(tweet_netral4)
panjang_tweet_netral5 = len(tweet_netral5)
panjang_tweet_netral6 = len(tweet_netral6)
panjang_tweet_netral7 = len(tweet_netral7)
panjang_tweet_netral8 = len(tweet_netral8)

# %%
label = []
for x in range(panjang_tweet_bundir1):
    label.append(4)
    
for x in range(panjang_tweet_bundir2):
    label.append(4)


for x in range(panjang_tweet_depresi1):
    label.append(3)
    

for x in range(panjang_tweet_depresi2):
    label.append(3)
    

for x in range(panjang_tweet_bully1):
    label.append(2)
    

for x in range(panjang_tweet_bully2):
    label.append(2)
    

for x in range(panjang_tweet_seks_abuse1):
    label.append(1)
    

for x in range(panjang_tweet_seks_abuse2):
    label.append(1)
    

for x in range(panjang_tweet_netral1):
    label.append(0)
    

for x in range(panjang_tweet_netral2):
    label.append(0)
    

for x in range(panjang_tweet_netral3):
    label.append(0)
    

for x in range(panjang_tweet_netral4):
    label.append(0)
    

for x in range(panjang_tweet_netral5):
    label.append(0)
    

for x in range(panjang_tweet_netral6):
    label.append(0)
    

for x in range(panjang_tweet_netral7):
    label.append(0)
    

for x in range(panjang_tweet_netral8):
    label.append(0)

# %%
len(label)
# Out:
# 45267

# %%
clean_test_result = []
clean_label = []

for count,x in enumerate(test_result):
    if x != "":
        clean_test_result.append(x)
        clean_label.append(label[count])

# %%
print(len(clean_test_result))
print(len(clean_label))
# Out:
# 43787
# 43787

# %%
clean_test_result
# Out:
# ['gua gamau terus menerus jadi benalu di lingkungan gua so kayanya lebih baik gua enyah dari muka bumi ini bye',
#  'it s really hurts',
#  'and i keep to myself fuck with no one else and i know it s my fault but i don t care',
#  'yeah all my friends no fun fuck my friends they re gone they all left one by one',
#  'gaberubah wkwkwk',
#  'yak',
#  'annisaa padahal seger',
#  'bye',
#  'still can t believe that',
#  'it s insane i love her so much',
#  'and it s finally done',
#  'there are no more days left',
#  'karna dugaan saya benar sekian dan terimakasih',
#  'done',
#  'coba deh ya ibu ini suruh nonton black mirror season eps judulnya arkangel that s how you re going to curate everythin',
#  'naini',
#  'one day left',
#  'atai kesel bat anjing',
#  'annisaa lucuuuuu',
#  'sensi sensi amat',
#  'pain pain go away come back another day i just wanna get one up on life before it kills me',
#  'sounds good',
#  'i am me out now listen',
#  'dopeeee mardial',
# ...

# %%
new_split = [x.split(" ") for x in clean_test_result]

# %%
len(new_split)
# Out:
# 43787

# %%
new_split[0]
# Out:
# ['gua',
#  'gamau',
#  'terus',
#  'menerus',
#  'jadi',
#  'benalu',
#  'di',
#  'lingkungan',
#  'gua',
#  'so',
#  'kayanya',
#  'lebih',
#  'baik',
#  'gua',
#  'enyah',
#  'dari',
#  'muka',
#  'bumi',
#  'ini',
#  'bye']

# %%
new_split
# Out:
# [['gua',
#   'gamau',
#   'terus',
#   'menerus',
#   'jadi',
#   'benalu',
#   'di',
#   'lingkungan',
#   'gua',
#   'so',
#   'kayanya',
#   'lebih',
#   'baik',
#   'gua',
#   'enyah',
#   'dari',
#   'muka',
#   'bumi',
#   'ini',
#   'bye'],
#  ['it', 's', 'really', 'hurts'],
#  ['and',
#   'i',
#   'keep',
#   'to',
#   'myself',
#   'fuck',
#   'with',
#   'no',
#   'one',
#   'else',
#   'and',
#   'i',
#   'know',
#   'it',
#   's',
#   'my',
#   'fault',
#   'but',
#   'i',
#   'don',
#   't',
#   'care'],
#  ['yeah',
#   'all',
#   'my',
#   'friends',
#   'no',
#   'fun',
#   'fuck',
#   'my',
#   'friends',
#   'they',
#   're',
#   'gone',
#   'they',
#   'all',
#   'left',
#   'one',
#   'by',
#   'one'],
#  ['gaberubah', 'wkwkwk'],
#  ['yak'],
#  ['annisaa', 'padahal', 'seger'],
#  ['bye'],
#  ['still', 'can', 't', 'believe', 'that'],
#  ['it', 's', 'insane', 'i', 'love', 'her', 'so', 'much'],
#  ['and', 'it', 's', 'finally', 'done'],
# ...

# %%
#For old school
# hahaha = []

# for x in clean_test_result:
#     hahaha.append(x.split(" "))

# %%
model_fasttext = FastText(sentences = new_split, window=7, min_count=1)

# %%
# import pickle
# pickle.dump(model_fasttext, open( "model_fasttext.pick", "wb" ) )
# # pickle.dump(tree, open( "depresi3_tree.pick", "wb" ) )
# # pickle.dump(ridge, open( "seksabuse3_ridge.pick", "wb" ) )
# # pickle.dump(clf, open( "netral9_nb.pick", "wb" ) )
# # pickle.dump(cls, open( "cls.p", "wb" ) )
# # pickle.dump(sgd, open( "sgd.p", "wb" ) )
# # pickle.dump(mlp, open( "mlp.p", "wb" ) )
# # pickle.dump(ran, open( "ran.p", "wb" ) )

# %%
kata_fasttext = []

for kalimat in new_split:
    hasil = np.zeros((100))
    for kata in kalimat:
        hasil += model_fasttext.wv[kata]
    kata_fasttext.append(hasil)

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(kata_fasttext, clean_label)
print(neigh.score(kata_fasttext, clean_label))
# Out:
# 0.7041130929271245

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier(random_state=0)
tree.fit(kata_fasttext, clean_label)
print(tree.score(kata_fasttext, clean_label))
# Out:
# 0.9937195971407039

# %%
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()
clf.fit(kata_fasttext, clean_label)
print(clf.score(kata_fasttext, clean_label))
# Out:
# 0.20508370064174297

# %%
from sklearn.ensemble import RandomForestClassifier
ran = RandomForestClassifier(max_depth=2, random_state=0)
ran.fit(kata_fasttext, clean_label)
print(ran.score(kata_fasttext, clean_label))
# Out:
# 0.5462580217872884

# %%
from sklearn import svm
cls = svm.SVC()
cls.fit(kata_fasttext, clean_label)
print(cls.score(kata_fasttext, clean_label))
# Out:
# 0.5538630187041816

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(random_state=1, max_iter=300)
mlp.fit(kata_fasttext, clean_label)
print(mlp.score(kata_fasttext, clean_label))
# Out:
# 0.5989448923196382

# %%
from sklearn.linear_model import RidgeClassifier
ridge = RidgeClassifier(alpha=1.0)
ridge.fit(kata_fasttext, clean_label)
print(ridge.score(kata_fasttext, clean_label))
# Out:
# 0.6050197547217211

# %%
from sklearn.linear_model import SGDClassifier
sgd = make_pipeline(StandardScaler(),SGDClassifier(max_iter=1000, tol=1e-3))
sgd.fit(kata_fasttext, clean_label)
print(sgd.score(kata_fasttext, clean_label))
# Out:
# 0.5607143672779592

# %% [markdown]
# # #Testing Depresi##

# %%
depresi3 = pd.read_csv('Data_Twitter/depresi/Theresiaaa30.csv')
tweet_depresi3 = depresi3.iloc[:,-1].values

# %%
tok = WordPunctTokenizer()
pat1 = r'@[A-Za-z0-9]+'
pat2 = r'https?://[A-Za-z0-9./]+'
pat3 = r'^RT[\s]+'
combined_pat = r'|'.join((pat1, pat2, pat3))
def tweet_cleaner(text):
    soup = BeautifulSoup(text, 'lxml')
    souped = soup.get_text()
    stripped = re.sub(combined_pat, '', souped)
    try:
        clean = stripped.decode("utf-8-sig").replace(u"\ufffd", "?")
    except:
        clean = stripped
    letters_only = re.sub("[^a-zA-Z]", " ", clean)
    lower_case = letters_only.lower()
    # During the letters_only process two lines above, it has created unnecessay white spaces,
    # I will tokenize and join together to remove unneccessary white spaces
    words = tok.tokenize(lower_case)
    return (" ".join(words)).strip()

testing_depresi3 = tweet_depresi3
test_result_depresi3 = []
for t in testing_depresi3:
    test_result_depresi3.append(tweet_cleaner(t))
test_result_depresi3
# Out:
# C:\Users\Arman\anaconda3\envs\develop1\lib\site-packages\bs4\__init__.py:424: MarkupResemblesLocatorWarning: "http://t.co/RK8fYw0FQE" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# C:\Users\Arman\anaconda3\envs\develop1\lib\site-packages\bs4\__init__.py:424: MarkupResemblesLocatorWarning: "http://t.co/ZTuRwERJ2d" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# ...

# %%
panjang_tweet_depresi3 = len(test_result_depresi3)
panjang_tweet_depresi3
# Out:
# 2812

# %%
label_test_depresi3 = []
for x in range(panjang_tweet_depresi3):
    label_test_depresi3.append(3)

# %%
len(label_test_depresi3)
# Out:
# 2812

# %%
clean_test_result_depresi3 = []
clean_label_test_depresi3 = []

for count,y in enumerate(test_result_depresi3):
    if x != "":
        clean_test_result_depresi3.append(y)
        clean_label_test_depresi3.append(label_test_depresi3[count])

# %%
print(len(clean_test_result_depresi3))
print(len(clean_label_test_depresi3))
# Out:
# 2812
# 2812

# %%
split_clean_test_result_depresi3 = []
for x in clean_test_result_depresi3:
    split_clean_test_result_depresi3.append(x.split(" "))

# %%
split_clean_test_result_depresi3
# Out:
# [['kurangi',
#   'gaenakan',
#   'mulai',
#   'perbanyak',
#   'bodoamatan',
#   'biar',
#   'gak',
#   'nyusahin',
#   'diri',
#   'sendiri'],
#  ['orang',
#   'ngeluh',
#   'capek',
#   'kok',
#   'dibilang',
#   'nggak',
#   'bersyukur',
#   'capek',
#   'mah',
#   'capek',
#   'aja',
#   'ngeluh',
#   'buat',
#   'ngurangi',
#   'rasa',
#   'capeknya',
#   'berat',
#   'amat',
#   'hidup',
#   'u'],
#  ['bener', 'bgt'],
#  ['gaboleh', 'nyerah', 'kan', 'anak', 'pertama', 'perempuan', 'pula'],
#  ['kadang',
#   'kita',
#   'juga',
#   'butuh',
#   'jeda',
#   'rehat',
#   'sejenak',
#   'evaluasi',
#   'sadar',
#   'diri',
#   'kadang',
#   'hal',
#   'yang',
#   'terlalu',
#   'dikejar',
#   'ambisius',
#   'meninggalkan',
#   'luka'],
#  ['yaa',
#   'lord',
#   'cuma',
#   'pengen',
#   'sempro',
#   'kok',
#   'rumit',
#   'amat',
#   'yaa',
#   'jalannya'],
#  ['masuk',
#   'lagi',
#   'ke',
#   'drama',
#   'nunggu',
#   'dosen',
#   'penguji',
#   'pengganti',
# ...

# %%
split_test_depresi3 = [x.split(" ") for x in clean_test_result_depresi3]

# %%
split_test_depresi3
# Out:
# [['kurangi',
#   'gaenakan',
#   'mulai',
#   'perbanyak',
#   'bodoamatan',
#   'biar',
#   'gak',
#   'nyusahin',
#   'diri',
#   'sendiri'],
#  ['orang',
#   'ngeluh',
#   'capek',
#   'kok',
#   'dibilang',
#   'nggak',
#   'bersyukur',
#   'capek',
#   'mah',
#   'capek',
#   'aja',
#   'ngeluh',
#   'buat',
#   'ngurangi',
#   'rasa',
#   'capeknya',
#   'berat',
#   'amat',
#   'hidup',
#   'u'],
#  ['bener', 'bgt'],
#  ['gaboleh', 'nyerah', 'kan', 'anak', 'pertama', 'perempuan', 'pula'],
#  ['kadang',
#   'kita',
#   'juga',
#   'butuh',
#   'jeda',
#   'rehat',
#   'sejenak',
#   'evaluasi',
#   'sadar',
#   'diri',
#   'kadang',
#   'hal',
#   'yang',
#   'terlalu',
#   'dikejar',
#   'ambisius',
#   'meninggalkan',
#   'luka'],
#  ['yaa',
#   'lord',
#   'cuma',
#   'pengen',
#   'sempro',
#   'kok',
#   'rumit',
#   'amat',
#   'yaa',
#   'jalannya'],
#  ['masuk',
#   'lagi',
#   'ke',
#   'drama',
#   'nunggu',
#   'dosen',
#   'penguji',
#   'pengganti',
# ...

# %%
depresi3_test_fasttext = []

for kalimat in split_test_depresi3:
    hasil = np.zeros((100))
    for kata in kalimat:
        hasil += model_fasttext.wv[kata]
    depresi3_test_fasttext.append(hasil)

# %%
len(depresi3_test_fasttext)
# Out:
# 2812

# %%
depresi3_n_pred = neigh.predict(depresi3_test_fasttext)
depresi3_t_pred = tree.predict(depresi3_test_fasttext)
depresi3_cf_pred = clf.predict(depresi3_test_fasttext)
depresi3_ra_pred = ran.predict(depresi3_test_fasttext)
depresi3_cs_pred = cls.predict(depresi3_test_fasttext)
depresi3_m_pred = mlp.predict(depresi3_test_fasttext)
depresi3_r_pred = ridge.predict(depresi3_test_fasttext)
depresi3_s_pred = sgd.predict(depresi3_test_fasttext)

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(list(depresi3_n_pred), clean_label_test_depresi3))
print(accuracy_score(list(depresi3_t_pred), clean_label_test_depresi3))
print(accuracy_score(list(depresi3_cf_pred), clean_label_test_depresi3))
print(accuracy_score(list(depresi3_ra_pred), clean_label_test_depresi3))
print(accuracy_score(list(depresi3_cs_pred), clean_label_test_depresi3))
print(accuracy_score(list(depresi3_m_pred), clean_label_test_depresi3))
print(accuracy_score(list(depresi3_r_pred), clean_label_test_depresi3))
print(accuracy_score(list(depresi3_s_pred), clean_label_test_depresi3))
# Out:
# 0.09246088193456614
# 0.17034139402560455
# 0.042318634423897585
# 0.0
# 0.0
# 0.032005689900426744
# 0.024893314366998577
# 0.0024893314366998577

# %%
import pickle
# pickle.dump(neigh, open( "neigh.p", "wb" ) )
pickle.dump(tree, open( "depresi3_tree.pick", "wb" ) )
# pickle.dump(ridge, open( "ridge.p", "wb" ) )
# pickle.dump(clf, open( "clf.p", "wb" ) )
# pickle.dump(cls, open( "cls.p", "wb" ) )
# pickle.dump(sgd, open( "sgd.p", "wb" ) )
# pickle.dump(mlp, open( "mlp.p", "wb" ) )
# pickle.dump(ran, open( "ran.p", "wb" ) )

# %% [markdown]
# # #Testing Bully

# %%
bully3 = pd.read_csv('Data_Twitter/korban_bully/legilimensal.csv')
tweet_bully3 = bully3.iloc[:,-1].values

# %%
tok = WordPunctTokenizer()
pat1 = r'@[A-Za-z0-9]+'
pat2 = r'https?://[A-Za-z0-9./]+'
pat3 = r'^RT[\s]+'
combined_pat = r'|'.join((pat1, pat2, pat3))
def tweet_cleaner(text):
    soup = BeautifulSoup(text, 'lxml')
    souped = soup.get_text()
    stripped = re.sub(combined_pat, '', souped)
    try:
        clean = stripped.decode("utf-8-sig").replace(u"\ufffd", "?")
    except:
        clean = stripped
    letters_only = re.sub("[^a-zA-Z]", " ", clean)
    lower_case = letters_only.lower()
    # During the letters_only process two lines above, it has created unnecessay white spaces,
    # I will tokenize and join together to remove unneccessary white spaces
    words = tok.tokenize(lower_case)
    return (" ".join(words)).strip()

testing_bully3 = combine
test_result_bully3 = []
for t in testing_bully3:
    test_result_bully3.append(tweet_cleaner(t))
test_result_bully3
# Out:
# C:\Users\Arman\anaconda3\envs\develop1\lib\site-packages\bs4\__init__.py:424: MarkupResemblesLocatorWarning: "https://t.co/ipya9JI8d5" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# C:\Users\Arman\anaconda3\envs\develop1\lib\site-packages\bs4\__init__.py:424: MarkupResemblesLocatorWarning: "https://t.co/3aulq4GmfH" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# ...

# %%
panjang_tweet_bully3 = len(test_result_bully3)
panjang_tweet_bully3
# Out:
# 45267

# %%
label_test_bully3 = []
for x in range(panjang_tweet_bully3):
    label_test_bully3.append(2)

# %%
clean_test_result_bully3 = []
clean_label_test_bully3 = []

for count,y in enumerate(test_result_bully3):
    if x != "":
        clean_test_result_bully3.append(y)
        clean_label_test_bully3.append(label_test_bully3[count])

# %%
print(len(clean_test_result_bully3))
print(len(clean_label_test_bully3))
# Out:
# 45267
# 45267

# %%
split_clean_test_result_bully3 = []
for x in clean_test_result_bully3:
    split_clean_test_result_bully3.append(x.split(" "))

# %%
len(split_clean_test_result_bully3)
# Out:
# 45267

# %%
bully3_test_fasttext = []

for kalimat in split_clean_test_result_bully3:
    hasil = np.zeros((100))
    for kata in kalimat:
        hasil += model_fasttext.wv[kata]
    bully3_test_fasttext.append(hasil)

# %%
len(bully3_test_fasttext)
# Out:
# 45267

# %%
bully3_n_pred = neigh.predict(bully3_test_fasttext)
bully3_t_pred = tree.predict(bully3_test_fasttext)
bully3_cf_pred = clf.predict(bully3_test_fasttext)
bully3_ra_pred = ran.predict(bully3_test_fasttext)
bully3_cs_pred = cls.predict(bully3_test_fasttext)
bully3_m_pred = mlp.predict(bully3_test_fasttext)
bully3_r_pred = ridge.predict(bully3_test_fasttext)
bully3_s_pred = sgd.predict(bully3_test_fasttext)

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(list(bully3_n_pred), clean_label_test_bully3))
print(accuracy_score(list(bully3_t_pred), clean_label_test_bully3))
print(accuracy_score(list(bully3_cf_pred), clean_label_test_bully3))
print(accuracy_score(list(bully3_ra_pred), clean_label_test_bully3))
print(accuracy_score(list(bully3_cs_pred), clean_label_test_bully3))
print(accuracy_score(list(bully3_m_pred), clean_label_test_bully3))
print(accuracy_score(list(bully3_r_pred), clean_label_test_bully3))
print(accuracy_score(list(bully3_s_pred), clean_label_test_bully3))
# Out:
# 0.11220094108290808
# 0.13614774559833875
# 0.0985927938674973
# 0.0
# 0.01740782468464886
# 0.08728212605209093
# 0.04868889036163209
# 0.0817151567366956

# %%
import pickle
# pickle.dump(neigh, open( "neigh.p", "wb" ) )
pickle.dump(tree, open( "bully3_tree.pick", "wb" ) )
# pickle.dump(ridge, open( "ridge.p", "wb" ) )
# pickle.dump(clf, open( "clf.p", "wb" ) )
# pickle.dump(cls, open( "cls.p", "wb" ) )
# pickle.dump(sgd, open( "sgd.p", "wb" ) )
# pickle.dump(mlp, open( "mlp.p", "wb" ) )
# pickle.dump(ran, open( "ran.p", "wb" ) )

# %% [markdown]
# # Testing Seksabuse

# %%
seksual_abuse3 = pd.read_csv('Data_Twitter/pelecehan_seksual/yqknit.csv')
tweet_seksual_abuse3 = seksual_abuse3.iloc[:,-1].values

# %%
len(tweet_seksual_abuse3)
# Out:
# 595

# %%
tok = WordPunctTokenizer()
pat1 = r'@[A-Za-z0-9]+'
pat2 = r'https?://[A-Za-z0-9./]+'
pat3 = r'^RT[\s]+'
combined_pat = r'|'.join((pat1, pat2, pat3))
def tweet_cleaner(text):
    soup = BeautifulSoup(text, 'lxml')
    souped = soup.get_text()
    stripped = re.sub(combined_pat, '', souped)
    try:
        clean = stripped.decode("utf-8-sig").replace(u"\ufffd", "?")
    except:
        clean = stripped
    letters_only = re.sub("[^a-zA-Z]", " ", clean)
    lower_case = letters_only.lower()
    # During the letters_only process two lines above, it has created unnecessay white spaces,
    # I will tokenize and join together to remove unneccessary white spaces
    words = tok.tokenize(lower_case)
    return (" ".join(words)).strip()

testing_seksual_abuse3 = tweet_seksual_abuse3
test_result_seksual_abuse3 = []
for t in testing_seksual_abuse3:
    test_result_seksual_abuse3.append(tweet_cleaner(t))
test_result_seksual_abuse3
# Out:
# ['base mutualan yukk rt rep nnti ku follow xoxo pong',
#  'assassin',
#  'base pong mutualan yuk like rt rep terserah jangan lupa follback ya f',
#  'kerennn thanks ya nder infonya',
#  'ok thanks ya infonya',
#  'ok thanks ya infonya',
#  'ok thanks ya infonya',
#  'ok thanks ya infonya',
#  'ayoo',
#  'asli sakit sih tuh orang urat malunya dah putus',
#  'iya tuh kalo gini kan lama jadi takut mau buka request chat',
#  'niceee kamu bener banget',
#  'dan pasang profil picture berhijab ternyata gak menjamin bakalan terhindar dari pelecehan seksual di sosial media ngenesss pisan',
#  'cape gak sih lu saban hari ngeblock orang gak jelas di twitter ngadepin ketololan mereka yg otaknya isinya cuma nafsu doang',
#  'lama lama gue takut maen twitter kalo gini caranya',
#  'wkwkwk',
#  'oke nanti aku follow',
#  'iyaa siapp',
#  'mau telur mata sapi sosis sama krupuknya jangan lupa ya',
#  'iyaa yang itu',
#  'barusan udah ku add',
#  'iya siap',
# ...

# %%
panjang_tweet_seksual_abuse3 = len(test_result_seksual_abuse3)
panjang_tweet_seksual_abuse3
# Out:
# 595

# %%
label_test_seksabuse3 = []
for x in range(panjang_tweet_seksual_abuse3):
    label_test_seksabuse3.append(1)

# %%
clean_test_result_seksabuse3 = []
clean_label_test_seksabuse3 = []

for count,y in enumerate(test_result_seksual_abuse3):
    if x != "":
        clean_test_result_seksabuse3.append(y)
        clean_label_test_seksabuse3.append(label_test_seksabuse3[count])

# %%
print(len(clean_test_result_seksabuse3))
print(len(clean_label_test_seksabuse3))
# Out:
# 595
# 595

# %%
split_clean_test_result_seksabuse3 = []
for x in clean_test_result_seksabuse3:
    split_clean_test_result_seksabuse3.append(x.split(" "))

# %%
len(split_clean_test_result_seksabuse3)
# Out:
# 595

# %%
seksabuse3_test_fasttext = []

for kalimat in split_clean_test_result_seksabuse3:
    hasil = np.zeros((100))
    for kata in kalimat:
        hasil += model_fasttext.wv[kata]
    seksabuse3_test_fasttext.append(hasil)

# %%
len(seksabuse3_test_fasttext)
# Out:
# 595

# %%
seksabuse3_n_pred = neigh.predict(seksabuse3_test_fasttext)
seksabuse3_t_pred = tree.predict(seksabuse3_test_fasttext)
seksabuse3_cf_pred = clf.predict(seksabuse3_test_fasttext)
seksabuse3_ra_pred = ran.predict(seksabuse3_test_fasttext)
seksabuse3_cs_pred = cls.predict(seksabuse3_test_fasttext)
seksabuse3_m_pred = mlp.predict(seksabuse3_test_fasttext)
seksabuse3_r_pred = ridge.predict(seksabuse3_test_fasttext)
seksabuse3_s_pred = sgd.predict(seksabuse3_test_fasttext)

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(list(seksabuse3_n_pred), clean_label_test_seksabuse3))
print(accuracy_score(list(seksabuse3_t_pred), clean_label_test_seksabuse3))
print(accuracy_score(list(seksabuse3_cf_pred), clean_label_test_seksabuse3))
print(accuracy_score(list(seksabuse3_ra_pred), clean_label_test_seksabuse3))
print(accuracy_score(list(seksabuse3_cs_pred), clean_label_test_seksabuse3))
print(accuracy_score(list(seksabuse3_m_pred), clean_label_test_seksabuse3))
print(accuracy_score(list(seksabuse3_r_pred), clean_label_test_seksabuse3))
print(accuracy_score(list(seksabuse3_s_pred), clean_label_test_seksabuse3))
# Out:
# 0.040336134453781515
# 0.058823529411764705
# 0.5663865546218487
# 0.0
# 0.0
# 0.03529411764705882
# 0.11428571428571428
# 0.040336134453781515

# %%
import pickle
# pickle.dump(neigh, open( "neigh.p", "wb" ) )
# pickle.dump(tree, open( "depresi3_tree.pick", "wb" ) )
pickle.dump(ridge, open( "seksabuse3_ridge.pick", "wb" ) )
# pickle.dump(clf, open( "clf.p", "wb" ) )
# pickle.dump(cls, open( "cls.p", "wb" ) )
# pickle.dump(sgd, open( "sgd.p", "wb" ) )
# pickle.dump(mlp, open( "mlp.p", "wb" ) )
# pickle.dump(ran, open( "ran.p", "wb" ) )

# %% [markdown]
# # Netral cuy

# %%
netral9 = pd.read_csv('Data_Twitter/netral/nvrss_.csv')
tweet_seksual_netral9 = netral9.iloc[:,-1].values

# %%
pat1 = r'@[A-Za-z0-9]+'
pat2 = r'https?://[A-Za-z0-9./]+'
pat3 = r'^RT[\s]+'
combined_pat = r'|'.join((pat1, pat2, pat3))
def tweet_cleaner(text):
    soup = BeautifulSoup(text, 'lxml')
    souped = soup.get_text()
    stripped = re.sub(combined_pat, '', souped)
    try:
        clean = stripped.decode("utf-8-sig").replace(u"\ufffd", "?")
    except:
        clean = stripped
    letters_only = re.sub("[^a-zA-Z]", " ", clean)
    lower_case = letters_only.lower()
    # During the letters_only process two lines above, it has created unnecessay white spaces,
    # I will tokenize and join together to remove unneccessary white spaces
    words = tok.tokenize(lower_case)
    return (" ".join(words)).strip()

testing_netral9 = tweet_seksual_netral9
test_result_netral9 = []
for t in testing_netral9:
    test_result_netral9.append(tweet_cleaner(t))
test_result_netral9
# Out:
# ['tiati disantet wkwkwkw',
#  'toner andalanku tetep cosrx aha bha cosrx centella water alcohol free hadalabo anti aging dah re',
#  'satu persatu doamu akan dikabul allah tepat pada waktunya percayalah',
#  'aku yg gak bisa make skincare yg ada kandunhan vit c nya hanya termenung',
#  'duwit',
#  '',
#  'e rarep ngopi wedi semaput',
#  'apaan mo foto ktp makeup yaallah w dulu gak sempet alias pulang sekolah muka kumel pas tau hasilnya menyesal',
#  'njeli sak donyo',
#  'beli tumbler lucu dimana bun',
#  'dah mlm',
#  'liat ini jadi pengen jga hes jan',
#  'aamiin yaallah aamiin',
#  'cidra iya lagi',
#  'ya ente apanya yg dibh in sob',
#  'kesehatan mahal harganya udah mahal masih aja ditambah penimbun di sana sini yang bikin harga makin nggak masuk akal',
#  'tidur kok pake bh',
#  'semenjak habis kena covid w kalo mo tidur was was mulu soalnya tiba tiba suka engap tapi kata dokter ndak papa',
#  'mo tidur repot bgt',
#  'tuhan aku menyayangi salah satu hambamu sungguh',
# ...

# %%
panjang_tweet_netral9 = len(test_result_netral9)
panjang_tweet_netral9
# Out:
# 3250

# %%
label_test_netral9 = []
for x in range(panjang_tweet_netral9):
    label_test_netral9.append(0)

# %%
clean_test_result_netral9 = []
clean_label_test_netral9 = []

for count,y in enumerate(test_result_netral9):
    if x != "":
        clean_test_result_netral9.append(y)
        clean_label_test_netral9.append(label_test_netral9[count])

# %%
print(len(clean_test_result_netral9))
print(len(clean_label_test_netral9))
# Out:
# 3250
# 3250

# %%
split_clean_test_result_netral9 = []
for x in clean_test_result_netral9:
    split_clean_test_result_netral9.append(x.split(" "))

# %%
len(split_clean_test_result_netral9)
# Out:
# 3250

# %%
netral9_test_fasttext = []

for kalimat in split_clean_test_result_netral9:
    hasil = np.zeros((100))
    for kata in kalimat:
        hasil += model_fasttext.wv[kata]
    netral9_test_fasttext.append(hasil)

# %%
len(netral9_test_fasttext)
# Out:
# 3250

# %%
netral9_n_pred = neigh.predict(netral9_test_fasttext)
netral9_t_pred = tree.predict(netral9_test_fasttext)
netral9_cf_pred = clf.predict(netral9_test_fasttext)
netral9_ra_pred = ran.predict(netral9_test_fasttext)
netral9_cs_pred = cls.predict(netral9_test_fasttext)
netral9_m_pred = mlp.predict(netral9_test_fasttext)
netral9_r_pred = ridge.predict(netral9_test_fasttext)
netral9_s_pred = sgd.predict(netral9_test_fasttext)

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(list(netral9_n_pred), clean_label_test_netral9))
print(accuracy_score(list(netral9_t_pred), clean_label_test_netral9))
print(accuracy_score(list(netral9_cf_pred), clean_label_test_netral9))
print(accuracy_score(list(netral9_ra_pred), clean_label_test_netral9))
print(accuracy_score(list(netral9_cs_pred), clean_label_test_netral9))
print(accuracy_score(list(netral9_m_pred), clean_label_test_netral9))
print(accuracy_score(list(netral9_r_pred), clean_label_test_netral9))
print(accuracy_score(list(netral9_s_pred), clean_label_test_netral9))
# Out:
# 0.699076923076923
# 0.39415384615384613
# 0.015692307692307693
# 1.0
# 0.9984615384615385
# 0.5252307692307693
# 0.9969230769230769
# 0.9766153846153847

# %%
import pickle
# pickle.dump(neigh, open( "neigh.p", "wb" ) )
# pickle.dump(tree, open( "depresi3_tree.pick", "wb" ) )
# pickle.dump(ridge, open( "seksabuse3_ridge.pick", "wb" ) )
pickle.dump(clf, open( "netral9_nb.pick", "wb" ) )
# pickle.dump(cls, open( "cls.p", "wb" ) )
# pickle.dump(sgd, open( "sgd.p", "wb" ) )
# pickle.dump(mlp, open( "mlp.p", "wb" ) )
# pickle.dump(ran, open( "ran.p", "wb" ) )

# %%
dir(FastText)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slotnames__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_adapt_by_suffix',
#  '_check_corpus_sanity',
#  '_check_training_sanity',
#  '_clear_post_train',
#  '_do_train_epoch',
#  '_do_train_job',
#  '_get_next_alpha',
#  '_get_thread_working_mem',
#  '_init_post_load',
#  '_job_producer',
#  '_load_specials',
#  '_log_epoch_end',
#  '_log_epoch_progress',
#  '_log_progress',
#  '_log_train_end',
#  '_raw_word_count',
#  '_save_specials',
#  '_scan_vocab',
#  '_smart_save',
#  '_train_epoch',
#  '_train_epoch_corpusfile',
#  '_worker_loop',
#  '_worker_loop_corpusfile',
#  'add_lifecycle_event',
# ...

# %%
from gensim.models import FastText

ft = FastText.load_fasttext_format('cc.id.300.bin.gz')
# Out:
# C:\Users\Arman\anaconda3\envs\develop1\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `load_fasttext_format` (use load_facebook_vectors (to use pretrained embeddings) or load_facebook_model (to continue training with the loaded full model, more RAM) instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\anaconda3\envs\develop1\lib\site-packages\gensim\models\fasttext.py in _load_fasttext_format(model_file, encoding, full_model)
#     796     with utils.open(model_file, 'rb') as fin:
# --> 797         m = gensim.models._fasttext_bin.load(fin, encoding=encoding, full_model=full_model)
#     798
#
# ~\anaconda3\envs\develop1\lib\site-packages\gensim\models\_fasttext_bin.py in load(fin, encoding, full_model)
#     347
# ...
